# %%
import pandas as pd
from functools import reduce
import string

# %%
pd.set_option('display.max_rows', None)

# %% [markdown]
# #Preparing Data

# %%
#reading the Excel file. Change the PATH to match file PATH
xlsx_data = pd.ExcelFile('/content/drive/MyDrive/Colab Notebooks/TASK1/INPUT.xlsx')

# %%
#Needed sheets for this work
selected_sheet=['OutputData','AllVisit','DiagnosisData','MedicationData']

# %%
# Read all needed sheets
sheet_to_df = {}
for sheet_index, sheet_name in enumerate(selected_sheet):
    sheet_to_df[sheet_name] = xlsx_data.parse(sheet_name)

# %%
#Convert alphabetic index to numerical index
def convert_index(value):
  if type(value) is list:
    return [reduce(lambda x, y: x*26 + y, [ord(c.upper()) - ord('A') + 1 for c in col]) for col in value]
  else:
    return reduce( lambda x, y: x*26 + y, [ord(c.upper()) - ord('A') + 1 for c in value])

# %%
#Selected Columns, The program add/remove columns dynamically from this list
selected_columns={
    'OutputData':['E','J','Q','T','U','W','X','DX',['OS','SV']],
    'AllVisit':['E','H','I','J','L','N','O','P','Q',['R','V'],'AA','AB',['AC','AF'],'AH',['CQ','EQ'],['LZ','MG'],['MT','MX'],['MY','NH']],
    'DiagnosisData':['D','E'],
    'MedicationData':['D','G','J','Q']
}

# %%
sheet_df_selected_columns = {}

for df_key, df_column_list in selected_columns.items():

  sheet_df_selected_columns[df_key]=pd.DataFrame()
  for column_index in df_column_list:

    if type(column_index) is list:#if the item is list
      start_column_index, end_column_index=convert_index(column_index) #return [start, end] of numeric index
      current_sub_df=sheet_to_df[df_key].iloc[:,start_column_index-1:end_column_index]# selected intended columns
      sheet_df_selected_columns[df_key]=pd.concat([sheet_df_selected_columns[df_key], current_sub_df],axis=1) # combined current column with previous once
    else:# if it string item
      current_column_index=sheet_to_df[df_key].iloc[:,convert_index(column_index)-1]#select current column
      sheet_df_selected_columns[df_key][current_column_index.name]=current_column_index# combined current column with previous once

# %% [markdown]
# # Combine **OutputData** sheet with **AllVisit** sheet

# %%
OutputData=sheet_df_selected_columns["OutputData"]
OutputData = OutputData.loc[(OutputData['PatientID'].notna()) & (OutputData['PatientID']>0),:]
display(len(OutputData),len(OutputData.columns),OutputData.head())

AllVisit=sheet_df_selected_columns["AllVisit"]
display(len(AllVisit),len(AllVisit.columns),AllVisit.head())
# Out:
# 1080
# 116
#    PatientID  Sex  Smoking(ever)  IgM_Value(Highest) IgM(evaluation)  \
# 0          2    1            1.0                 NaN        Negative
# 1          3    0            0.0               162.0        Positive
# 2          4    0            NaN                 NaN             NaN
# 3          5    1            NaN                 NaN             NaN
# 4          6    1            NaN                 NaN             NaN
#
#    aCCP_Value(Highest) aCCP(evaluation) First_Biologic(StartDate)  \
# 0                  1.0         Negative                       NaT
# 1                 56.0         Positive                2023-10-27
# 2                  NaN              NaN                2020-09-24
# 3                  NaN              NaN                2021-01-12
# 4                  NaN              NaN                       NaT
#
#    COMORB_Cancer COMORB_Cancer(StartDate)  ...  COMORB_PulmHypertens  \
# 0            0.0                      NaT  ...                   0.0
# 1            0.0                      NaT  ...                   0.0
# 2            0.0                      NaT  ...                   0.0
# 3            0.0                      NaT  ...                   0.0
# 4            NaN                      NaT  ...                   NaN
#
#    COMORB_PulmHypertens(StartDate)  COMORB_Sinusitis  \
# 0                              NaN               0.0
# 1                              NaN               0.0
# 2                              NaN               0.0
# 3                              NaN               0.0
# 4                              NaN               NaN
#
#   COMORB_Sinusitis(StartDate)  COMORB_SubglStenosis  \
# 0                         NaT                   0.0
# 1                         NaT                   0.0
# 2                         NaT                   0.0
# 3                         NaT                   0.0
# 4                         NaT                   NaN
#
#   COMORB_SubglStenosis(StartDate)  COMORB_Bronchitis  \
# 0                             NaN                0.0
# 1                             NaN                0.0
# 2                             NaN                0.0
# 3                             NaN                0.0
# 4                             NaN                NaN
#
#   COMORB_Bronchitis(StartDate)  COMORB_HemorrhAlveol  \
# 0                          NaN                   0.0
# 1                          NaN                   0.0
# 2                          NaN                   0.0
# 3                          NaN                   0.0
# 4                          NaN                   NaN
#
#   COMORB_HemorrhAlveol(StartDate)
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN
#
# [5 rows x 116 columns]
# 4057
# 97
#    PatientID AV_Visit_Date  AV_Age AV_Work_status  AV_Smoking(now)  \
# 0          2    2021-07-07      51  Full-time job              0.0
# 1          2    2021-07-08      51  Full-time job              0.0
# 2          2    2021-09-10      51  Full-time job              0.0
# 3          2    2022-07-19      52  Full-time job              0.0
# 4          3    2020-02-03      43            NaN              NaN
#
#    AV_Years_of_education  AV_Height  AV_Weight  AV_BMI  AV_ESR  ...  \
# 0                   16.0      178.0       80.0    25.2     NaN  ...
# 1                   16.0      178.0       80.0    25.2     NaN  ...
# 2                   16.0      178.0       80.0    25.2     NaN  ...
# 3                   16.0      178.0       80.0    25.2     NaN  ...
# 4                    NaN        NaN        NaN     NaN    18.0  ...
#
#    AV_WPAI_RA_Absenteeism  AV_WPAI_RA_Presenteeism  \
# 0                     NaN                      NaN
# 1                     NaN                      NaN
# 2                     NaN                      NaN
# 3                     NaN                      NaN
# 4                     NaN                      NaN
#
#    AV_WPAI_RA_WorkProductivityLoss  AV_WPAI_RA_ActivityImpairment  \
# 0                              NaN                            NaN
# 1                              NaN                            NaN
# 2                              NaN                            NaN
# 3                              NaN                            NaN
# 4                              NaN                            NaN
#
#    AV_WPAI_RA_Q1_PAID_EMPLOYMENT  AV_WPAI_RA_Q2_HOURS_MISSED_WORK_REASON_RA  \
# 0                            NaN                                        NaN
# 1                            NaN                                        NaN
# 2                            NaN                                        NaN
# 3                            NaN                                        NaN
# 4                            NaN                                        NaN
#
#    AV_WPAI_RA_Q3_HOURS_MISSED_WORK_REASON_OTHER  AV_WPAI_RA_Q4_HOURS_WORKED  \
# 0                                           NaN                         NaN
# 1                                           NaN                         NaN
# 2                                           NaN                         NaN
# 3                                           NaN                         NaN
# 4                                           NaN                         NaN
#
#    AV_WPAI_RA_Q5_RA_EFFECT_WORK  AV_WPAI_RA_Q6_RA_EFFECT_DAILY_ACTIVITIES
# 0                           NaN                                       NaN
# 1                           NaN                                       NaN
# 2                           NaN                                       NaN
# 3                           NaN                                       NaN
# 4                           NaN                                       NaN
#
# [5 rows x 97 columns]

# %%
temp_AllVisit=pd.merge(AllVisit,OutputData[["PatientID","First_Biologic(StartDate)"]], on="PatientID", how="left")
display(len(temp_AllVisit),len(temp_AllVisit.columns),temp_AllVisit.head())
# Out:
# 4057
# 98
#    PatientID AV_Visit_Date  AV_Age AV_Work_status  AV_Smoking(now)  \
# 0          2    2021-07-07      51  Full-time job              0.0
# 1          2    2021-07-08      51  Full-time job              0.0
# 2          2    2021-09-10      51  Full-time job              0.0
# 3          2    2022-07-19      52  Full-time job              0.0
# 4          3    2020-02-03      43            NaN              NaN
#
#    AV_Years_of_education  AV_Height  AV_Weight  AV_BMI  AV_ESR  ...  \
# 0                   16.0      178.0       80.0    25.2     NaN  ...
# 1                   16.0      178.0       80.0    25.2     NaN  ...
# 2                   16.0      178.0       80.0    25.2     NaN  ...
# 3                   16.0      178.0       80.0    25.2     NaN  ...
# 4                    NaN        NaN        NaN     NaN    18.0  ...
#
#    AV_WPAI_RA_Presenteeism  AV_WPAI_RA_WorkProductivityLoss  \
# 0                      NaN                              NaN
# 1                      NaN                              NaN
# 2                      NaN                              NaN
# 3                      NaN                              NaN
# 4                      NaN                              NaN
#
#    AV_WPAI_RA_ActivityImpairment  AV_WPAI_RA_Q1_PAID_EMPLOYMENT  \
# 0                            NaN                            NaN
# 1                            NaN                            NaN
# 2                            NaN                            NaN
# 3                            NaN                            NaN
# 4                            NaN                            NaN
#
#    AV_WPAI_RA_Q2_HOURS_MISSED_WORK_REASON_RA  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#    AV_WPAI_RA_Q3_HOURS_MISSED_WORK_REASON_OTHER  AV_WPAI_RA_Q4_HOURS_WORKED  \
# 0                                           NaN                         NaN
# 1                                           NaN                         NaN
# 2                                           NaN                         NaN
# 3                                           NaN                         NaN
# 4                                           NaN                         NaN
#
#    AV_WPAI_RA_Q5_RA_EFFECT_WORK  AV_WPAI_RA_Q6_RA_EFFECT_DAILY_ACTIVITIES  \
# 0                           NaN                                       NaN
# 1                           NaN                                       NaN
# 2                           NaN                                       NaN
# 3                           NaN                                       NaN
# 4                           NaN                                       NaN
#
#    First_Biologic(StartDate)
# 0                        NaT
# 1                        NaT
# 2                        NaT
# 3                        NaT
# 4                 2023-10-27
#
# [5 rows x 98 columns]

# %%
filter= (temp_AllVisit["First_Biologic(StartDate)"].isna()) | (temp_AllVisit["AV_Visit_Date"].isna()) | (temp_AllVisit["First_Biologic(StartDate)"]>temp_AllVisit["AV_Visit_Date"])
temp_AllVisit=temp_AllVisit.loc[filter,:].drop_duplicates(['PatientID'], keep='last')
temp_AllVisit.drop(columns=["First_Biologic(StartDate)"],axis=1,inplace=True)

# %%
OutputData_Final=pd.merge(OutputData,temp_AllVisit, on="PatientID", how="left")

# %%
OutputData_Final[OutputData_Final["PatientID"]==88]["AV_Visit_Date"]
# Out:
# 85   2023-01-19
# Name: AV_Visit_Date, dtype: datetime64[ns]

# %% [markdown]
# # Combine **OutputData** sheet with **DiagnosisData** sheet

# %%
display(OutputData_Final.head())
display(sheet_df_selected_columns["DiagnosisData"].head())
# Out:
#    PatientID  Sex  Smoking(ever)  IgM_Value(Highest) IgM(evaluation)  \
# 0          2    1            1.0                 NaN        Negative
# 1          3    0            0.0               162.0        Positive
# 2          4    0            NaN                 NaN             NaN
# 3          5    1            NaN                 NaN             NaN
# 4          6    1            NaN                 NaN             NaN
#
#    aCCP_Value(Highest) aCCP(evaluation) First_Biologic(StartDate)  \
# 0                  1.0         Negative                       NaT
# 1                 56.0         Positive                2023-10-27
# 2                  NaN              NaN                2020-09-24
# 3                  NaN              NaN                2021-01-12
# 4                  NaN              NaN                       NaT
#
#    COMORB_Cancer COMORB_Cancer(StartDate)  ...  AV_WPAI_RA_Absenteeism  \
# 0            0.0                      NaT  ...                     NaN
# 1            0.0                      NaT  ...                     0.0
# 2            0.0                      NaT  ...                     NaN
# 3            0.0                      NaT  ...                     NaN
# 4            NaN                      NaT  ...                     NaN
#
#    AV_WPAI_RA_Presenteeism  AV_WPAI_RA_WorkProductivityLoss  \
# 0                      NaN                              NaN
# 1                     20.0                             20.0
# 2                      NaN                              NaN
# 3                      NaN                              NaN
# 4                      NaN                              NaN
#
#   AV_WPAI_RA_ActivityImpairment  AV_WPAI_RA_Q1_PAID_EMPLOYMENT  \
# 0                           NaN                            NaN
# 1                          30.0                            1.0
# 2                           NaN                            NaN
# 3                           NaN                            NaN
# 4                           NaN                            NaN
#
#   AV_WPAI_RA_Q2_HOURS_MISSED_WORK_REASON_RA  \
# 0                                       NaN
# 1                                       0.0
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#    AV_WPAI_RA_Q3_HOURS_MISSED_WORK_REASON_OTHER AV_WPAI_RA_Q4_HOURS_WORKED  \
# 0                                           NaN                        NaN
# 1                                           0.0                       48.0
# 2                                           NaN                        NaN
# 3                                           NaN                        NaN
# 4                                           NaN                        NaN
#
#    AV_WPAI_RA_Q5_RA_EFFECT_WORK AV_WPAI_RA_Q6_RA_EFFECT_DAILY_ACTIVITIES
# 0                           NaN                                      NaN
# 1                           2.0                                      3.0
# 2                           NaN                                      NaN
# 3                           NaN                                      NaN
# 4                           NaN                                      NaN
#
# [5 rows x 212 columns]
#    PatientID           DiagnosisName
# 0          2    Rheumatoid Arthritis
# 1          3    Rheumatoid Arthritis
# 2          4  Ankylosing Spondylitis
# 3          5  Ankylosing Spondylitis
# 4          5          Joint disorder

# %%
#only extract Rheumatoid Arthritis
convert_DiagnosisData=sheet_df_selected_columns["DiagnosisData"].loc[(sheet_df_selected_columns["DiagnosisData"]["DiagnosisName"]=="Rheumatoid Arthritis"),:]
#re-structuring the df
convert_DiagnosisData=convert_DiagnosisData.groupby("PatientID").count().reset_index()
convert_DiagnosisData.columns=["PatientID","hasRheumatoidArthritis"]

# %%
#users with two Rheumatoid Arthritis
convert_DiagnosisData[convert_DiagnosisData["hasRheumatoidArthritis"]==2]
# Out:
#      PatientID  hasRheumatoidArthritis
# 2            7                       2
# 251        527                       2
# 289        603                       2
# 304        632                       2
# 375        764                       2
# 445        949                       2

# %%
#users with three Rheumatoid Arthritis
convert_DiagnosisData[convert_DiagnosisData["hasRheumatoidArthritis"]==3]
# Out:
#      PatientID  hasRheumatoidArthritis
# 280        590                       3

# %%
convert_DiagnosisData.loc[convert_DiagnosisData["hasRheumatoidArthritis"]>1, 'hasRheumatoidArthritis'] = 1

# %%
#meging the sheets
OutputData_Final=pd.merge(OutputData_Final, convert_DiagnosisData, on="PatientID", how="left")
#fill NaN values
OutputData_Final["hasRheumatoidArthritis"].fillna(0, inplace = True)

# %%
# The statistic of new column
OutputData_Final["hasRheumatoidArthritis"].value_counts()
# Out:
# 0.0    568
# 1.0    512
# Name: hasRheumatoidArthritis, dtype: int64

# %% [markdown]
# # Combine **OutputData** sheet with **MedicationData** sheet

# %%
# Show data
MedicationData=sheet_df_selected_columns["MedicationData"]
display(len(MedicationData),MedicationData["MedicamentGroupName"].unique(),MedicationData.head())
# Out:
# 3494
# array(['BIOLOGICS', 'OTHER/SUPPLEMENTS', 'DMARD', 'NSAID/COXIB'],
#       dtype=object)
#    PatientID MedicamentGroupName  StartDate    EndDate
# 0          3           BIOLOGICS 2023-10-27        NaT
# 1          3   OTHER/SUPPLEMENTS 2020-06-15 2022-03-18
# 2          3   OTHER/SUPPLEMENTS 2022-05-20 2023-04-26
# 3          3               DMARD 2020-06-15 2020-10-05
# 4          3               DMARD 2023-03-22 2023-04-26

# %%
# this function BIOLOGICS Medicament, and only return other Medicament that had been used before using BIOLOGICS Medicament
def medication_data_filtering(rows):
  #Find  the date for [BIOLOGICS]
  biologic_start_date=rows[rows["MedicamentGroupName"]=="BIOLOGICS"]["StartDate"].min()

  filtering= (rows["MedicamentGroupName"]!="BIOLOGICS") # remove BIOLOGICS rows

  if biologic_start_date is not pd.NaT:
    filtering=filtering & (rows["StartDate"]<biologic_start_date) # reomve sample after BIOLOGICS

  df_row=rows.loc[filtering,["MedicamentGroupName","StartDate","EndDate"]]

  df_row["StopDate"]= (biologic_start_date - df_row["EndDate"]).dt.days
  return df_row

# %%
# group samples based on [PatientID]
MedicationData=MedicationData.groupby("PatientID").apply(lambda rows: medication_data_filtering(rows)).reset_index()

#drop not needed column
MedicationData.drop(columns=["level_1"],axis=1,inplace=True)
#sort samples
MedicationData.sort_values(by=["PatientID","MedicamentGroupName","StartDate"],inplace=True)

#Create new columns
MedicationData["period"]=(MedicationData["EndDate"]-MedicationData["StartDate"]).dt.days
MedicationData["isActive"]=MedicationData["EndDate"].isna()

# %%
MedicationData.head(20)
# Out:
#     PatientID MedicamentGroupName  StartDate    EndDate  StopDate  period  \
# 4           3               DMARD 2020-04-02 2023-06-15     134.0  1169.0
# 2           3               DMARD 2020-06-15 2020-10-05    1117.0   112.0
# 3           3               DMARD 2023-03-22 2023-04-26     184.0    35.0
# 7           3               DMARD 2023-04-26 2023-04-28     182.0     2.0
# 5           3               DMARD 2023-10-15        NaT       NaN     NaN
# 6           3         NSAID/COXIB 2020-07-13 2022-03-18     588.0   613.0
# 0           3   OTHER/SUPPLEMENTS 2020-06-15 2022-03-18     588.0   641.0
# 1           3   OTHER/SUPPLEMENTS 2022-05-20 2023-04-26     184.0   341.0
# 8           4         NSAID/COXIB 2019-09-14 2020-08-17      38.0   338.0
# 9           4         NSAID/COXIB 2020-08-17 2020-11-01     -38.0    76.0
# 10          6         NSAID/COXIB 2021-01-12        NaT       NaN     NaN
# 11         11               DMARD 2018-12-19 2019-02-06       NaN    49.0
# 12         11               DMARD 2019-02-26 2019-06-12       NaN   106.0
# 13         11               DMARD 2019-08-14 2021-01-13       NaN   518.0
# 14         11               DMARD 2021-01-13 2021-01-19       NaN     6.0
# 17         15               DMARD 2016-05-20 2016-09-26    1402.0   129.0
# 16         15               DMARD 2016-09-22 2016-10-22    1376.0    30.0
# 15         15               DMARD 2017-05-31 2017-06-07    1148.0     7.0
# 18         16               DMARD 2021-01-15        NaT       NaN     NaN
# 20         17               DMARD 2021-05-24        NaT       NaN     NaN
#
#     isActive
# 4      False
# 2      False
# 3      False
# 7      False
# 5       True
# 6      False
# 0      False
# 1      False
# 8      False
# 9      False
# 10      True
# 11     False
# 12     False
# 13     False
# 14     False
# 17     False
# 16     False
# 15     False
# 18      True
# 20      True

# %%
MedicationData=MedicationData.groupby(by=["PatientID","MedicamentGroupName"]).agg({
    'MedicamentGroupName' : ['count'],
    'period' : ['sum'],                           # sums all sessions period
    'StopDate' : ['min'],                           # min meaning the stoping for latest session
    'isActive' : lambda value: True in set(value) # check if any sessions are still active
}).reset_index()

MedicationData.columns=["PatientID","MedicamentGroupName","Multi","Period","StopDate","isActive"]
# if it has a treatment only once and still on going then convert it to -1
MedicationData.loc[(MedicationData["Period"]==0) & (MedicationData["isActive"]==True) & (MedicationData["Multi"]==1),["Period"]]=-1

# %%
MedicationData=pd.pivot_table(
    MedicationData,
    columns=['MedicamentGroupName'],
    values=["Multi","Period",'StopDate',"isActive"],
    index=['PatientID'],
    #fill_value=0
)
#swapping multi index coming from group by
MedicationData.columns = MedicationData.columns.swaplevel(0, 1)
#sorting index
MedicationData.sort_index(axis=1, level=0, inplace=True)
#changing style
MedicationData.columns = MedicationData.columns.to_flat_index().map(lambda x: x[0]+str("_"+x[1]))
MedicationData.reset_index(inplace=True)

# %%
MedicationData.head()
# Out:
#    PatientID  DMARD_Multi  DMARD_Period  DMARD_StopDate  DMARD_isActive  \
# 0          3          5.0        1318.0           134.0             1.0
# 1          4          NaN           NaN             NaN             NaN
# 2          6          NaN           NaN             NaN             NaN
# 3         11          4.0         679.0             NaN             0.0
# 4         15          3.0         166.0          1148.0             0.0
#
#    NSAID/COXIB_Multi  NSAID/COXIB_Period  NSAID/COXIB_StopDate  \
# 0                1.0               613.0                 588.0
# 1                2.0               414.0                 -38.0
# 2                1.0                -1.0                   NaN
# 3                NaN                 NaN                   NaN
# 4                NaN                 NaN                   NaN
#
#    NSAID/COXIB_isActive  OTHER/SUPPLEMENTS_Multi  OTHER/SUPPLEMENTS_Period  \
# 0                   0.0                      2.0                     982.0
# 1                   0.0                      NaN                       NaN
# 2                   1.0                      NaN                       NaN
# 3                   NaN                      NaN                       NaN
# 4                   NaN                      NaN                       NaN
#
#    OTHER/SUPPLEMENTS_StopDate  OTHER/SUPPLEMENTS_isActive
# 0                       184.0                         0.0
# 1                         NaN                         NaN
# 2                         NaN                         NaN
# 3                         NaN                         NaN
# 4                         NaN                         NaN

# %%
print(len(MedicationData))
print(MedicationData["PatientID"].nunique())
# Out:
# 698
# 698

# %%
#meging the sheets
OutputData_Final=pd.merge(OutputData_Final, MedicationData, on="PatientID", how="left")
OutputData_Final[MedicationData.columns.difference(['PatientID'])]=OutputData_Final[MedicationData.columns.difference(['PatientID'])].fillna(0)

# %%
display(OutputData_Final[OutputData_Final["PatientID"]==4]["AV_Visit_Date"])
# display(OutputData_Final[OutputData_Final["PatientID"]==11]["AV_Visit_Date"])
# Out:
# 2   2020-08-17
# Name: AV_Visit_Date, dtype: datetime64[ns]

# %%
OutputData_Final[OutputData_Final["PatientID"]==4]["AV_Visit_Date"]
# Out:
# 2   2020-08-17
# Name: AV_Visit_Date, dtype: datetime64[ns]

# %% [markdown]
# #Saving Output in File

# %%
#saving the output
OutputData_Final.to_csv('/content/drive/MyDrive/Colab Notebooks/TASK1/OUTPUT.csv', index=False)

# %% [markdown]
# #Questions

# %% [markdown]
# ### Could you, please, write to me how many patients with rheumathoid arthritic do we have in total.

# %%
# They don't have value_counts==0
# They have value_counts==1

OutputData_Final["hasRheumatoidArthritis"].value_counts()
# Out:
# 0.0    568
# 1.0    512
# Name: hasRheumatoidArthritis, dtype: int64

# %% [markdown]
# ### how many with biological treatment among them

# %%
df_q2=OutputData_Final.loc[(OutputData_Final["hasRheumatoidArthritis"]==1) & (OutputData_Final["First_Biologic(StartDate)"].notnull()),:]

print(f'Number of heumathoid arthritic patients who have biological treatment {len(df_q2)}')


df_q2[["PatientID","hasRheumatoidArthritis","First_Biologic(StartDate)"]].head()
# Out:
# Number of heumathoid arthritic patients who have biological treatment 215
#     PatientID  hasRheumatoidArthritis First_Biologic(StartDate)
# 1           3                     1.0                2023-10-27
# 5           7                     1.0                2019-10-24
# 10         12                     1.0                2021-01-14
# 11         13                     1.0                2018-03-13
# 23         26                     1.0                2020-11-02

# %% [markdown]
# ### Could you, please, summarize how big is the problem of missing data?

# %%
print(f'Dataset Shape {OutputData_Final.shape}')
# Out:
# Dataset Shape (1080, 225)

# %% [markdown]
# #### For each column

# %%
OutputData_Final.isnull().sum(axis = 0)
# Out:
# PatientID                                          0
# Sex                                                0
# Smoking(ever)                                    132
# IgM_Value(Highest)                               460
# IgM(evaluation)                                  420
# aCCP_Value(Highest)                              549
# aCCP(evaluation)                                 511
# First_Biologic(StartDate)                        533
# COMORB_Cancer                                    263
# COMORB_Cancer(StartDate)                        1079
# COMORB_AIDS                                      263
# COMORB_AIDS(StartDate)                          1080
# COMORB_InfectReqHospital                         263
# COMORB_InfectReqHospital(StartDate)             1079
# COMORB_ThyroidDis                                263
# COMORB_ThyroidDis(StartDate)                    1040
# COMORB_DiabetesMell                              263
# COMORB_DiabetesMell(StartDate)                  1067
# COMORB_Hyperlipidemia                            263
# COMORB_Hyperlipidemia(StartDate)                 942
# COMORB_PsychiatricDis                            263
# COMORB_PsychiatricDis(StartDate)                1077
# COMORB_Smoking                                   263
# COMORB_Smoking(StartDate)                       1069
# COMORB_Alcoholism                                263
# COMORB_Alcoholism(StartDate)                    1079
# COMORB_ParkinsonDis                              263
# COMORB_ParkinsonDis(StartDate)                  1079
# COMORB_Stroke                                    263
# COMORB_Stroke(StartDate)                        1078
# COMORB_Cataract                                  263
# COMORB_Cataract(StartDate)                      1067
# COMORB_ArterialHypert                            263
# COMORB_ArterialHypert(StartDate)                 768
# COMORB_CoronArteryDis                            263
# COMORB_CoronArteryDis(StartDate)                1071
# COMORB_MyocardInfarct                            263
# COMORB_MyocardInfarct(StartDate)                1067
# COMORB_PeriArteVascDis                           263
# COMORB_PeriArteVascDis(StartDate)               1077
# COMORB_OtherHeartDis                             263
# COMORB_OtherHeartDis(StartDate)                 1075
# COMORB_Asthma                                    263
# COMORB_Asthma(StartDate)                        1021
# COMORB_ChronObstrLungDis                         263
# COMORB_ChronObstrLungDis(StartDate)             1069
# COMORB_PepticUlcer                               263
# COMORB_PepticUlcer(StartDate)                   1072
# COMORB_IBD                                       263
# COMORB_IBD(StartDate)                           1078
# COMORB_Celiac                                    263
# COMORB_Celiac(StartDate)                        1078
# COMORB_Psoriasis                                 263
# COMORB_Psoriasis(StartDate)                      979
# COMORB_OsteoporBoneDens                          263
# COMORB_OsteoporBoneDens(StartDate)              1022
# COMORB_LowEnergyFract                            263
# COMORB_LowEnergyFract(StartDate)                1079
# COMORB_Fibromyalgia                              263
# COMORB_Fibromyalgia(StartDate)                  1047
# COMORB_Osteoarthritis                            263
# COMORB_Osteoarthritis(StartDate)                1067
# COMORB_ImpairedRenalFunc                         263
# COMORB_ImpairedRenalFunc(StartDate)             1073
# COMORB_MuskuloskelTrauma                         263
# COMORB_MuskuloskelTrauma(StartDate)             1080
# COMORB_ChronicBackPain                           263
# COMORB_ChronicBackPain(StartDate)               1074
# COMORB_Polyneuropathy                            263
# COMORB_Polyneuropathy(StartDate)                1073
# COMORB_IridocyclUveitis                          263
# COMORB_IridocyclUveitis(StartDate)              1042
# COMORB_Scleritis                                 263
# COMORB_Scleritis(StartDate)                     1078
# COMORB_AortaInsuff                               263
# COMORB_AortaInsuff(StartDate)                   1078
# COMORB_Pericarditis                              263
# COMORB_Pericarditis(StartDate)                  1080
# COMORB_HeartRhythmDis                            263
# COMORB_HeartRhythmDis(StartDate)                1069
# COMORB_RheumaNodules                             263
# COMORB_RheumaNodules(StartDate)                 1079
# COMORB_SjögrenSyndr                              263
# COMORB_SjögrenSyndr(StartDate)                  1072
# COMORB_Other                                     263
# COMORB_Other(StartDate)                         1051
# COMORB_PulmFibrosis                              263
# COMORB_PulmFibrosis(StartDate)                  1078
# COMORB_Mononeuritis                              263
# COMORB_Mononeuritis(StartDate)                  1079
# COMORB_Vasculitis                                263
# COMORB_Vasculitis(StartDate)                    1080
# COMORB_Pleurisy                                  263
# COMORB_Pleurisy(StartDate)                      1080
# COMORB_SecondAmyloido                            263
# COMORB_SecondAmyloido(StartDate)                1080
# COMORB_FeltySyndrome                             263
# COMORB_FeltySyndrome(StartDate)                 1080
# COMORB_Lymphadenopathy                           263
# COMORB_Lymphadenopathy(StartDate)               1080
# COMORB_RaynaudPhenom                             263
# COMORB_RaynaudPhenom(StartDate)                 1078
# COMORB_Aortitis                                  263
# COMORB_Aortitis(StartDate)                      1080
# COMORB_SkinUlcer                                 263
# COMORB_SkinUlcer(StartDate)                     1080
# COMORB_PulmHypertens                             263
# COMORB_PulmHypertens(StartDate)                 1080
# COMORB_Sinusitis                                 263
# COMORB_Sinusitis(StartDate)                     1068
# COMORB_SubglStenosis                             263
# COMORB_SubglStenosis(StartDate)                 1080
# COMORB_Bronchitis                                263
# COMORB_Bronchitis(StartDate)                    1080
# COMORB_HemorrhAlveol                             263
# COMORB_HemorrhAlveol(StartDate)                 1080
# AV_Visit_Date                                    394
# AV_Age                                           394
# AV_Work_status                                   511
# AV_Smoking(now)                                  502
# AV_Years_of_education                            586
# AV_Height                                        498
# AV_Weight                                        496
# AV_BMI                                           499
# AV_ESR                                           542
# AV_CRP                                           527
# AV_Inv._global                                   565
# AV_SJC28                                         561
# AV_TJC28                                         561
# AV_SJC_66                                        694
# AV_TJC_68                                        694
# AV_DAS28(4)                                      651
# AV_DAS28(3)                                      639
# AV_DAS28-CRP(4)                                  638
# AV_DAS28-CRP(3)                                  626
# AV_CDAI                                          770
# AV_M-HAQ                                         538
# AV_MDHAQ_(FN)                                    582
# AV_MDHAQ_(PS)                                    581
# AV_HAQ(0-3)                                      575
# AV_Raw_HAQ                                       575
# AV_HAQ_Q-DRESS                                   538
# AV_HAQ_Q-BED                                     539
# AV_HAQ_Q-CUP                                     537
# AV_HAQ_Q-WALK_OUTDOOR                            538
# AV_HAQ_Q-WASH_BODY                               538
# AV_HAQ_Q-PICK_UP_FLOOR                           538
# AV_HAQ_Q-FAUCET                                  538
# AV_HAQ_Q-IN_OUT_CAR                              540
# AV_HAQ_Q-SHAMPOO                                 576
# AV_HAQ_Q-CHAIR                                   577
# AV_HAQ_Q-MEAT                                    577
# AV_HAQ_Q-MILK                                    577
# AV_HAQ_Q-CLIMB5                                  578
# AV_HAQ_PART1DEV-CANE                            1069
# AV_HAQ_PART1DEV-WALKER                          1076
# AV_HAQ_PART1DEV-CRUTCHES                        1065
# AV_HAQ_PART1DEV-WHEELCHAIR                      1076
# AV_HAQ_PART1DEV-DEVICE_DRESSING                 1027
# AV_HAQ_PART1DEV-SPECIAL_UTENSIL                 1077
# AV_HAQ_PART1DEV-SPECIAL_CHAIR                   1076
# AV_HAQ_PART1DEV-OTHER_device1                   1041
# AV_HAQ_PART1ASS-DRESS_GROOM                     1039
# AV_HAQ_PART1ASS-EATING                          1065
# AV_HAQ_PART1ASS-ARISING                         1038
# AV_HAQ_PART1ASS-WALKING                         1049
# AV_HAQ_Q-TUB_BATH                                576
# AV_HAQ_Q-TOILETT                                 578
# AV_HAQ_Q-5POUND_OBJECT                           575
# AV_HAQ_Q-CAR_DOOR                                577
# AV_HAQ_Q-OPEN_JAR                                575
# AV_HAQ_Q-ERRAND_SHOP                             575
# AV_HAQ_Q-CHORES                                  576
# AV_HAQ_PART2DEV-RAISE_TOILET_SEAT               1069
# AV_HAQ_PART2DEV-BATHTUB_BAR                     1017
# AV_HAQ_PART2DEV-BATHTUB_SEAT                    1064
# AV_HAQ_PART2DEV-LONG_REACH                      1053
# AV_HAQ_PART2DEV-JAR_OPENER                       952
# AV_HAQ_PART2DEV-LONG_BATHROOM                   1028
# AV_HAQ_PART2DEV-OTHER_device2                   1054
# AV_HAQ_PART2ASS-HYGIENE                         1063
# AV_HAQ_PART2ASS-GRIPPING_OPENING                 934
# AV_HAQ_PART2ASS-REACH                            971
# AV_HAQ_PART2ASS-ERRAND_CHORE                     996
# AV_HAQ_Q-SLEEP                                   581
# AV_HAQ_Q-STRESS                                  581
# AV_HAQ_Q-ANXIETY                                 582
# AV_HAQ_Q-DEPRESSION                              582
# AV_Pain                                          553
# AV_RAND-12 MH                                    827
# AV_RAND-12 VT                                    827
# AV_RAND-12 BP                                    827
# AV_RAND-12 GH                                    827
# AV_RAND-12 SF                                    827
# AV_RAND-12 PF                                    828
# AV_RAND-12 RP                                    829
# AV_RAND-12 RE                                    829
# AV_Health state_MOBILITY                         648
# AV_Health state_SELF_CARE                        647
# AV_Health state_USUAL_ACTIVITY                   648
# AV_Health state_PAIN_DISCOMFORT                  648
# AV_Health state_ANXIETY_DEPRESSION               648
# AV_WPAI_RA_Absenteeism                           975
# AV_WPAI_RA_Presenteeism                          974
# AV_WPAI_RA_WorkProductivityLoss                  979
# AV_WPAI_RA_ActivityImpairment                    860
# AV_WPAI_RA_Q1_PAID_EMPLOYMENT                    859
# AV_WPAI_RA_Q2_HOURS_MISSED_WORK_REASON_RA        967
# AV_WPAI_RA_Q3_HOURS_MISSED_WORK_REASON_OTHER     965
# AV_WPAI_RA_Q4_HOURS_WORKED                       966
# AV_WPAI_RA_Q5_RA_EFFECT_WORK                     974
# AV_WPAI_RA_Q6_RA_EFFECT_DAILY_ACTIVITIES         860
# hasRheumatoidArthritis                             0
# DMARD_Multi                                        0
# DMARD_Period                                       0
# DMARD_StopDate                                     0
# DMARD_isActive                                     0
# NSAID/COXIB_Multi                                  0
# NSAID/COXIB_Period                                 0
# NSAID/COXIB_StopDate                               0
# NSAID/COXIB_isActive                               0
# OTHER/SUPPLEMENTS_Multi                            0
# OTHER/SUPPLEMENTS_Period                           0
# OTHER/SUPPLEMENTS_StopDate                         0
# OTHER/SUPPLEMENTS_isActive                         0
# dtype: int64

# %% [markdown]
# #### For each row

# %%
OutputData_Final.isnull().sum(axis = 1)
# Out:
# 0       144
# 1        75
# 2       150
# 3       154
# 4       154
# 5       149
# 6       154
# 7       149
# 8       154
# 9        94
# 10      148
# 11      151
# 12      153
# 13      153
# 14      136
# 15       87
# 16      139
# 17      137
# 18      198
# 19       83
# 20      154
# 21      152
# 22      151
# 23      204
# 24      150
# 25      204
# 26      150
# 27       91
# 28      149
# 29      153
# 30      147
# 31       85
# 32       84
# 33      148
# 34      147
# 35      150
# 36      148
# 37      108
# 38      152
# 39      154
# 40      151
# 41      207
# 42       83
# 43      147
# 44      147
# 45       81
# 46      149
# 47      149
# 48      204
# 49      149
# 50      148
# 51      149
# 52      149
# 53       94
# 54      151
# 55      152
# 56      208
# 57      101
# 576     153
# 577      78
# 578     146
# 579     162
# 580      83
# 581     150
# 582     174
# 583      98
# 584      89
# 585      76
# 586     161
# 587     191
# 588     187
# 589     135
# 590     133
# 591     132
# 592     133
# 593     131
# 594     150
# 595     100
# 596      86
# 597     130
# 598      75
# 599     188
# 600     132
# 601     134
# 602     133
# 603     104
# 604     134
# 605      94
# 606     132
# 607     140
# 608      86
# 609     151
# 610     148
# 611     106
# 612      78
# 613     145
# 614     121
# 615     104
# 616     142
# 617     130
# 618      92
# 619      84
# 620     208
# 621      99
# 622     139
# 623     149
# 624     106
# 625     141
# 626      96
# 627     150
# 628     149
# 629     154
# 630     102
# 631     159
# 632      84
# 633     131
# 634     131
# 635      91
# 636      91
# 637      91
# 638     155
# 639      96
# 640     187
# 641      84
# 642     132
# 643      83
# 644      81
# 645     154
# 646      78
# 647     208
# 648     204
# 649     164
# 650     192
# 651      92
# 652      94
# 653     149
# 654     209
# 655     133
# 656     159
# 657     136
# 658      85
# 659     155
# 660     149
# 661     209
# 662     138
# 663     136
# 664     149
# 665     209
# 666     187
# 667      95
# 668     139
# 669     146
# 670     132
# 671     149
# 672     209
# 673      89
# 674     149
# 675     154
# 676      88
# 677      77
# 678     134
# 679     134
# 680      91
# 681     155
# 682     152
# 683      73
# 684      80
# 685     133
# 686     152
# 687     154
# 688     150
# 689     133
# 690     208
# 691     101
# 692     147
# 693     153
# 694     209
# 695     152
# 696     147
# 697     153
# 698     131
# 699     101
# 700     135
# 701     134
# 702     130
# 703     150
# 704      91
# 705      78
# 706     209
# 707     209
# 708      83
# 709     149
# 710     138
# 711     132
# 712      81
# 713     150
# 714     189
# 715     105
# 716     132
# 717     128
# 718     130
# 719     139
# 720     138
# 721      78
# 722     129
# 723     189
# 724      89
# 725     134
# 726     208
# 727     149
# 728     155
# 729      97
# 730     103
# 731     155
# 732     209
# 733     107
# 734      82
# 735      81
# 736     148
# 737     134
# 738     152
# 739     152
# 740     159
# 741     150
# 742      85
# 743      80
# 744     152
# 745      99
# 746     192
# 747     135
# 748      97
# 749     151
# 750     206
# 751     154
# 752     136
# 753      84
# 754      84
# 755     128
# 756     154
# 757      99
# 758     206
# 759     206
# 760      95
# 761     149
# 762     153
# 763     136
# 764     152
# 765     130
# 766     152
# 767     153
# 768     104
# 769     102
# 770      83
# 771     105
# 772      78
# 773     153
# 774     204
# 775     207
# 776      73
# 777      95
# 778     154
# 779     208
# 780     132
# 781     204
# 782      96
# 783     131
# 784     102
# 785      90
# 786     133
# 787     134
# 788      97
# 789      81
# 790     137
# 791      96
# 792     153
# 793      87
# 794      89
# 795     185
# 796     144
# 797     130
# 798      93
# 799      84
# 800     151
# 801     204
# 802      90
# 803      87
# 804      96
# 805      88
# 806     101
# 807     149
# 808     154
# 809     101
# 810      85
# 811      75
# 812     132
# 813      83
# 814     140
# 815     148
# 816     136
# 817     129
# 818      97
# 819     152
# 820     154
# 821      90
# 822     208
# 823     151
# 824     133
# 825     203
# 826     150
# 827     134
# 828     152
# 829     154
# 830      77
# 831      81
# 832      87
# 833      85
# 834      96
